# %%
from models.unet.unet_dataloader import UNetDataloader
import matplotlib.pyplot as plt

# %%
dataloader = UNetDataloader(
    data_root_path = "/nfs/home/clruben/workspace/nst/data/reg",
    dataset_name = "train",
    size_limit = None
)

# %%
loader_iter = iter(dataloader)

# %%
img1, img2 = next(loader_iter)

# %%
splice_index = 3
plt.imshow(img1[splice_index,0,:,:], cmap='gray')

# %%
plt.imshow(img2[splice_index,0,:,:], cmap="gray")

# %%
mask = img1[1,0,:,:]!=1024/(1024+3071)
plt.imshow(mask)

# %%
# Out:
# 0.25006105006105006
