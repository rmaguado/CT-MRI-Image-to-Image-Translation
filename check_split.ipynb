# %%
import matplotlib.pyplot as plt
from dataloaders import Dataset, Dataloader

# %%
mr = Dataset("./data/batch1", "train", "MR", batch_size=4)

# %%
ite = iter(mr)

# %%
img1 = next(ite)

# %%
img1.shape
# Out:
# (4, 1, 512, 512)

# %%
plt.imshow(img1[0, 0, :, :])

# %%
splice_index = 3
plt.imshow(img1[splice_index,0,:,:], cmap='gray')

# %%
plt.imshow(img2[splice_index,0,:,:], cmap="gray")

# %%
mask = img1[1,0,:,:]!=1024/(1024+3071)
plt.imshow(mask)

# %%
# Out:
# 0.25006105006105006
